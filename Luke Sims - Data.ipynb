# %%
import pandas as pd
import numpy as np
import requests
import json
import gzip
import zipfile
import csv 
from datetime import datetime

#3 Dictionaries Present 

#minfo
#reviews
#df_movies_api
#meta_data

# %%
minfo=pd.read_csv('zippedData/rt.movie_info.tsv.gz',sep='\t')
reviews=pd.read_csv('zippedData/rt.reviews.tsv.gz',sep ='\t',encoding='latin1')

# %% [markdown]
# # Inspecting  - Movie Information List Cleaning!

# %%
#A basic overview of the first 5 rows!
minfo.head(10)
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
# 5   8  The year is 1942. As the Allies unite overseas...     PG
# 6  10  Some cast and crew from NBC's highly acclaimed...  PG-13
# 7  13  Stewart Kane, an Irishman living in the Austra...      R
# 8  14  "Love Ranch" is a bittersweet love story that ...      R
# 9  15  When a diamond expedition in the Congo is lost...  PG-13
#
#                                                genre          director  \
# 0                Action and Adventure|Classics|Drama  William Friedkin
# 1                  Drama|Science Fiction and Fantasy  David Cronenberg
# ...

# %%
minfo['synopsis'][1]
# Out:
# "New York City, not-too-distant-future: Eric Packer, a 28 year-old finance golden boy dreaming of living in a civilization ahead of this one, watches a dark shadow cast over the firmament of the Wall Street galaxy, of which he is the uncontested king. As he is chauffeured across midtown Manhattan to get a haircut at his father's old barber, his anxious eyes are glued to the yuan's exchange rate: it is mounting against all expectations, destroying Eric's bet against it. Eric Packer is losing his empire with every tick of the clock. Meanwhile, an eruption of wild activity unfolds in the city's streets. Petrified as the threats of the real world infringe upon his cloud of virtual convictions, his paranoia intensifies during the course of his 24-hour cross-town odyssey. Packer starts to piece together clues that lead him to a most terrifying secret: his imminent assassination. -- (C) Official Site"

# %%
minfo.dtypes
# Out:
# id               int64
# synopsis        object
# rating          object
# genre           object
# director        object
# writer          object
# theater_date    object
# dvd_date        object
# currency        object
# box_office      object
# runtime         object
# studio          object
# dtype: object

# %%
#Checking NA's in files
minfo.isna().sum()
# Out:
# id                 0
# synopsis          62
# rating             3
# genre              8
# director         199
# writer           449
# theater_date     359
# dvd_date         359
# currency        1220
# box_office      1220
# runtime           30
# studio          1066
# dtype: int64

# %%
minfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1560 non-null   int64
#  1   synopsis      1498 non-null   object
#  2   rating        1557 non-null   object
#  3   genre         1552 non-null   object
#  4   director      1361 non-null   object
#  5   writer        1111 non-null   object
#  6   theater_date  1201 non-null   object
#  7   dvd_date      1201 non-null   object
#  8   currency      340 non-null    object
#  9   box_office    340 non-null    object
#  10  runtime       1530 non-null   object
#  11  studio        494 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 146.4+ KB

# %%
#Dropping all columns both irrelevant and littered with NA's
minfo.drop(columns = ['synopsis', 'currency', 'dvd_date', 'theater_date'], inplace=True )

# %%
minfo_boxoffice= minfo['box_office']
minfo_boxoffice.sort_values()
# Out:
# 86      1,000,000
# 15      1,039,869
# 809     1,110,286
# 1087    1,121,000
# 1213    1,149,350
#           ...
# 1554          NaN
# 1556          NaN
# 1557          NaN
# 1558          NaN
# 1559          NaN
# Name: box_office, Length: 1560, dtype: object

# %%
minfo.dropna()
# Out:
#         id rating                                              genre  \
# 1        3      R                  Drama|Science Fiction and Fantasy
# 6       10  PG-13                                             Comedy
# 7       13      R                                              Drama
# 15      22      R                  Comedy|Drama|Mystery and Suspense
# 18      25  PG-13  Action and Adventure|Drama|Science Fiction and...
# ...    ...    ...                                                ...
# 1530  1968     PG                                       Comedy|Drama
# 1537  1976     NR   Action and Adventure|Art House and International
# 1541  1980  PG-13   Action and Adventure|Science Fiction and Fantasy
# 1542  1981     NR                                       Comedy|Drama
# 1545  1985      R                        Horror|Mystery and Suspense
#
#                  director                                writer  box_office  \
# ...

# %% [markdown]
# # Looking at Movie Info

# %%
minfo['rating'].value_counts()
# Out:
# R        521
# NR       503
# PG       240
# PG-13    235
# G         57
# NC17       1
# Name: rating, dtype: int64

# %%
m_box = minfo['box_office'].dropna() #Sort this
m_box
# Out:
# 1          600,000
# 6       41,032,915
# 7          224,114
# 8          134,904
# 15       1,039,869
#            ...
# 1541    25,335,935
# 1542     1,416,189
# 1545        59,371
# 1546       794,306
# 1555    33,886,034
# Name: box_office, Length: 340, dtype: object

# %% [markdown]
# 1. We Want to consider relationship between run time and box office
# 2. Relationship between rating and box office
# 3. find similar writers and directors and if larger correlation

# %%
m_dir = minfo['director']
m_dir.value_counts()
# Out:
# Steven Spielberg    10
# Clint Eastwood       8
# Alfred Hitchcock     4
# Curtis Hanson        4
# William Friedkin     4
#                     ..
# John Maybury         1
# Bob Badway           1
# Michael Rhodes       1
# Heiner Carow         1
# David Koepp          1
# Name: director, Length: 1125, dtype: int64

# %%
m_writ = minfo['writer']
m_writ.value_counts()
# Out:
# Woody Allen                      4
# Jim Jarmusch                     3
# John Hughes                      3
# Sylvester Stallone               3
# Hong Sang-soo                    3
#                                 ..
# Zak Penn|Ernest Cline            1
# Eric Rohmer                      1
# Paul Pender                      1
# Shawn Christensen|Jason Dolan    1
# David Koepp                      1
# Name: writer, Length: 1069, dtype: int64

# %%
minfo['runtime'].value_counts()
# Out:
# 90 minutes     72
# 95 minutes     66
# 100 minutes    51
# 93 minutes     47
# 96 minutes     43
#                ..
# 171 minutes     1
# 64 minutes      1
# 159 minutes     1
# 183 minutes     1
# 166 minutes     1
# Name: runtime, Length: 142, dtype: int64

# %%
m_genre = minfo['genre']
m_genre.value_counts()

#parsing through the mult titles
# Out:
# Drama                                                                                                                151
# Comedy                                                                                                               110
# Comedy|Drama                                                                                                          80
# Drama|Mystery and Suspense                                                                                            67
# Art House and International|Drama                                                                                     62
#                                                                                                                     ...
# Classics|Documentary|Drama|Romance                                                                                     1
# Action and Adventure|Art House and International|Drama|Faith and Spirituality                                          1
# ...

# %%
minfo.head()
# Out:
#    id rating                                genre          director  \
# 0   1      R  Action and Adventure|Classics|Drama  William Friedkin
# 1   3      R    Drama|Science Fiction and Fantasy  David Cronenberg
# 2   5      R    Drama|Musical and Performing Arts    Allison Anders
# 3   6      R           Drama|Mystery and Suspense    Barry Levinson
# 4   7     NR                        Drama|Romance    Rodney Bennett
#
#                             writer box_office      runtime             studio
# 0                   Ernest Tidyman        NaN  104 minutes                NaN
# 1     David Cronenberg|Don DeLillo    600,000  108 minutes  Entertainment One
# 2                   Allison Anders        NaN  116 minutes                NaN
# 3  Paul Attanasio|Michael Crichton        NaN  128 minutes                NaN
# 4                     Giles Cooper        NaN  200 minutes                NaN

# %% [markdown]
# # Cleaning Movie Info

# %%
minfo['writer'] = minfo['writer'].str.replace('|', ' ')

# %%
minfo
# Out:
#         id rating                                              genre  \
# 0        1      R                Action and Adventure|Classics|Drama
# 1        3      R                  Drama|Science Fiction and Fantasy
# 2        5      R                  Drama|Musical and Performing Arts
# 3        6      R                         Drama|Mystery and Suspense
# 4        7     NR                                      Drama|Romance
# ...    ...    ...                                                ...
# 1555  1996      R   Action and Adventure|Horror|Mystery and Suspense
# 1556  1997     PG                 Comedy|Science Fiction and Fantasy
# 1557  1998      G  Classics|Comedy|Drama|Musical and Performing Arts
# 1558  1999     PG    Comedy|Drama|Kids and Family|Sports and Fitness
# 1559  2000      R  Action and Adventure|Art House and Internation...
#
#                 director                                            writer  \
# ...

# %% [markdown]
# # Inspecting at Reviews

# %%
reviews.head()
# Out:
#    id                                             review rating   fresh  \
# 0   3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1   3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2   3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3   3  Continuing along a line introduced in last yea...    NaN   fresh
# 4   3             ... a perverse twist on neorealism...     NaN   fresh
#
#            critic  top_critic         publisher               date
# 0      PJ Nabarro           0   Patrick Nabarro  November 10, 2018
# 1  Annalee Newitz           0           io9.com       May 23, 2018
# 2    Sean Axmaker           0  Stream on Demand    January 4, 2018
# 3   Daniel Kasman           0              MUBI  November 16, 2017
# 4             NaN           0      Cinema Scope   October 12, 2017

# %%
reviews.dtypes
# Out:
# id             int64
# review        object
# rating        object
# fresh         object
# critic        object
# top_critic     int64
# publisher     object
# date          object
# dtype: object

# %%
reviews.isna().sum()
# Out:
# id                0
# review         5563
# rating        13517
# fresh             0
# critic         2722
# top_critic        0
# publisher       309
# date              0
# dtype: int64

# %%
reviews.drop(columns = ['rating', 'review', 'critic','top_critic'], inplace=True)

# %%
reviews.info
# Out:
# <bound method DataFrame.info of          id   fresh         publisher                date
# 0         3   fresh   Patrick Nabarro   November 10, 2018
# 1         3  rotten           io9.com        May 23, 2018
# 2         3   fresh  Stream on Demand     January 4, 2018
# 3         3   fresh              MUBI   November 16, 2017
# 4         3   fresh      Cinema Scope    October 12, 2017
# ...     ...     ...               ...                 ...
# 54427  2000   fresh     Village Voice  September 24, 2002
# 54428  2000  rotten        Zap2it.com  September 21, 2005
# 54429  2000  rotten   EmanuelLevy.Com       July 17, 2005
# 54430  2000  rotten    Filmcritic.com   September 7, 2003
# 54431  2000   fresh      Showbizz.net   November 12, 2002
#
# [54432 rows x 4 columns]>

# %%
reviews.head()
# Out:
#    id   fresh         publisher               date
# 0   3   fresh   Patrick Nabarro  November 10, 2018
# 1   3  rotten           io9.com       May 23, 2018
# 2   3   fresh  Stream on Demand    January 4, 2018
# 3   3   fresh              MUBI  November 16, 2017
# 4   3   fresh      Cinema Scope   October 12, 2017

# %%
m_genre.describe()
# Out:
# count      1552
# unique      299
# top       Drama
# freq        151
# Name: genre, dtype: object

# %% [markdown]
# # Looking at Reviews

# %%
pub_review = reviews['publisher']
pub_review.value_counts()
# Out:
# eFilmCritic.com                    673
# EmanuelLevy.Com                    591
# New York Times                     590
# Washington Post                    565
# Entertainment Weekly               541
#                                   ...
# Movie Guys with Jeff &amp; Dave      1
# The Jacobin                          1
# Nerve.com                            1
# CineGods.com                         1
# Elements of Madness                  1
# Name: publisher, Length: 1281, dtype: int64

# %%
fresh_review = reviews['fresh']
fresh_review.value_counts()
# Out:
# fresh     33035
# rotten    21397
# Name: fresh, dtype: int64

# %% [markdown]
# # Extras - API Upload

# %%
import requests
import pandas as pd
import json

url = 'http://www.omdbapi.com/?i=tt3896198&apikey=668487ac'

# %%
movie_response = requests.get(url)

# %%
movie_response.status_code
# Out:
# 200

# %%
type(movie_response)
# Out:
# requests.models.Response

# %%
movie_response.text
# Out:
# '{"Title":"Guardians of the Galaxy Vol. 2","Year":"2017","Rated":"PG-13","Released":"05 May 2017","Runtime":"136 min","Genre":"Action, Adventure, Comedy","Director":"James Gunn","Writer":"James Gunn, Dan Abnett, Andy Lanning","Actors":"Chris Pratt, Zoe Saldana, Dave Bautista","Plot":"The Guardians struggle to keep together as a team while dealing with their personal family issues, notably Star-Lord\'s encounter with his father the ambitious celestial being Ego.","Language":"English","Country":"United States","Awards":"Nominated for 1 Oscar. 15 wins & 60 nominations total","Poster":"https://m.media-amazon.com/images/M/MV5BNjM0NTc0NzItM2FlYS00YzEwLWE0YmUtNTA2ZWIzODc2OTgxXkEyXkFqcGdeQXVyNTgwNzIyNzg@._V1_SX300.jpg","Ratings":[{"Source":"Internet Movie Database","Value":"7.6/10"},{"Source":"Rotten Tomatoes","Value":"85%"},{"Source":"Metacritic","Value":"67/100"}],"Metascore":"67","imdbRating":"7.6","imdbVotes":"691,435","imdbID":"tt3896198","Type":"movie","DVD":"22 Aug 2017","BoxOffice":"
# ...

# %%
movie_data = movie_response.json()
movie_data.keys()
# Out:
# dict_keys(['Title', 'Year', 'Rated', 'Released', 'Runtime', 'Genre', 'Director', 'Writer', 'Actors', 'Plot', 'Language', 'Country', 'Awards', 'Poster', 'Ratings', 'Metascore', 'imdbRating', 'imdbVotes', 'imdbID', 'Type', 'DVD', 'BoxOffice', 'Production', 'Website', 'Response'])

# %%
movie_data
# Out:
# {'Title': 'Guardians of the Galaxy Vol. 2',
#  'Year': '2017',
#  'Rated': 'PG-13',
#  'Released': '05 May 2017',
#  'Runtime': '136 min',
#  'Genre': 'Action, Adventure, Comedy',
#  'Director': 'James Gunn',
#  'Writer': 'James Gunn, Dan Abnett, Andy Lanning',
#  'Actors': 'Chris Pratt, Zoe Saldana, Dave Bautista',
#  'Plot': "The Guardians struggle to keep together as a team while dealing with their personal family issues, notably Star-Lord's encounter with his father the ambitious celestial being Ego.",
#  'Language': 'English',
#  'Country': 'United States',
#  'Awards': 'Nominated for 1 Oscar. 15 wins & 60 nominations total',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNjM0NTc0NzItM2FlYS00YzEwLWE0YmUtNTA2ZWIzODc2OTgxXkEyXkFqcGdeQXVyNTgwNzIyNzg@._V1_SX300.jpg',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.6/10'},
#   {'Source': 'Rotten Tomatoes', 'Value': '85%'},
#   {'Source': 'Metacritic', 'Value': '67/100'}],
#  'Metascore': '67',
# ...

# %%
#Converting the Dict to a DF
df_movies_api = pd.DataFrame(movie_data)
df_movies_api
# Out:
#                             Title  Year  Rated     Released  Runtime  \
# 0  Guardians of the Galaxy Vol. 2  2017  PG-13  05 May 2017  136 min
# 1  Guardians of the Galaxy Vol. 2  2017  PG-13  05 May 2017  136 min
# 2  Guardians of the Galaxy Vol. 2  2017  PG-13  05 May 2017  136 min
#
#                        Genre    Director  \
# 0  Action, Adventure, Comedy  James Gunn
# 1  Action, Adventure, Comedy  James Gunn
# 2  Action, Adventure, Comedy  James Gunn
#
#                                  Writer  \
# 0  James Gunn, Dan Abnett, Andy Lanning
# 1  James Gunn, Dan Abnett, Andy Lanning
# 2  James Gunn, Dan Abnett, Andy Lanning
#
#                                     Actors  \
# 0  Chris Pratt, Zoe Saldana, Dave Bautista
# 1  Chris Pratt, Zoe Saldana, Dave Bautista
# 2  Chris Pratt, Zoe Saldana, Dave Bautista
#
#                                                 Plot  ... Metascore  \
# 0  The Guardians struggle to keep together as a t...  ...        67
# ...

# %% [markdown]
# # Cleaning

# %%
df_movies_api.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 25 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       3 non-null      object
#  1   Year        3 non-null      object
#  2   Rated       3 non-null      object
#  3   Released    3 non-null      object
#  4   Runtime     3 non-null      object
#  5   Genre       3 non-null      object
#  6   Director    3 non-null      object
#  7   Writer      3 non-null      object
#  8   Actors      3 non-null      object
#  9   Plot        3 non-null      object
#  10  Language    3 non-null      object
#  11  Country     3 non-null      object
#  12  Awards      3 non-null      object
#  13  Poster      3 non-null      object
#  14  Ratings     3 non-null      object
#  15  Metascore   3 non-null      object
#  16  imdbRating  3 non-null      object
#  17  imdbVotes   3 non-null      object
#  18  imdbID      3 non-null      object
# ...

# %%
df_movies_api['imdbRating']
# Out:
# 0    7.6
# 1    7.6
# 2    7.6
# Name: imdbRating, dtype: object

# %%
#Removing unnecessary info
df_movies_api.drop(columns = ['imdbID','Ratings','Poster','Awards','Country','Language','Plot','imdbVotes','DVD','Production','Website','Response'], inplace=True )

# %%
#Modifying the box office column to remove dollar signs and decimals to sort through
df_movies_api['BoxOffice'] = df_movies_api['BoxOffice'].str.replace('$', '')
df_movies_api['BoxOffice'] = df_movies_api['BoxOffice'].str.replace(',', '')
df_movies_api['BoxOffice'] = df_movies_api['BoxOffice'].astype(int)

# %%
df_movies_api
# Out:
#                             Title  Year  Rated     Released  Runtime  \
# 0  Guardians of the Galaxy Vol. 2  2017  PG-13  05 May 2017  136 min
# 1  Guardians of the Galaxy Vol. 2  2017  PG-13  05 May 2017  136 min
# 2  Guardians of the Galaxy Vol. 2  2017  PG-13  05 May 2017  136 min
#
#                        Genre    Director  \
# 0  Action, Adventure, Comedy  James Gunn
# 1  Action, Adventure, Comedy  James Gunn
# 2  Action, Adventure, Comedy  James Gunn
#
#                                  Writer  \
# 0  James Gunn, Dan Abnett, Andy Lanning
# 1  James Gunn, Dan Abnett, Andy Lanning
# 2  James Gunn, Dan Abnett, Andy Lanning
#
#                                     Actors Metascore imdbRating   Type  \
# 0  Chris Pratt, Zoe Saldana, Dave Bautista        67        7.6  movie
# 1  Chris Pratt, Zoe Saldana, Dave Bautista        67        7.6  movie
# 2  Chris Pratt, Zoe Saldana, Dave Bautista        67        7.6  movie
#
#    BoxOffice
# 0  389813101
# 1  389813101
# 2  389813101

# %% [markdown]
# # Extras - Movie Meta Data

# %%
csv_file_path = ('Extra Data/movies_metadata.csv')

# %%
meta_data = pd.read_csv(r'C:\Users\Luke Sims\Documents\Flatiron\Microsoft_Film_Project\Extra Data\movies_metadata.csv')
meta_data
# Out:
# C:\Users\Luke Sims\anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# ...

# %%
meta_data.drop(columns = ['genres','production_countries','original_title','id','original_language','imdb_id','poster_path','production_companies','vote_count','tagline','status','spoken_languages','overview','homepage','belongs_to_collection','video','vote_count'], inplace=True )

# %%
meta_data
# Out:
#        adult    budget popularity release_date      revenue  runtime  \
# 0      False  30000000    21.9469   1995-10-30  373554033.0     81.0
# 1      False  65000000    17.0155   1995-12-15  262797249.0    104.0
# 2      False         0    11.7129   1995-12-22          0.0    101.0
# 3      False  16000000    3.85949   1995-12-22   81452156.0    127.0
# 4      False         0    8.38752   1995-02-10   76578911.0    106.0
# ...      ...       ...        ...          ...          ...      ...
# 45461  False         0   0.072051          NaN          0.0     90.0
# 45462  False         0   0.178241   2011-11-17          0.0    360.0
# 45463  False         0   0.903007   2003-08-01          0.0     90.0
# 45464  False         0   0.003503   1917-10-21          0.0     87.0
# 45465  False         0   0.163015   2017-06-09          0.0     75.0
#
#                              title  vote_average
# 0                        Toy Story           7.7
# ...

# %%
#Converted The time into hours

meta_data['runtime'] = meta_data['runtime']/60

# %%
meta_data
# Out:
#        adult    budget popularity release_date      revenue   runtime  \
# 0      False  30000000    21.9469   1995-10-30  373554033.0  1.350000
# 1      False  65000000    17.0155   1995-12-15  262797249.0  1.733333
# 2      False         0    11.7129   1995-12-22          0.0  1.683333
# 3      False  16000000    3.85949   1995-12-22   81452156.0  2.116667
# 4      False         0    8.38752   1995-02-10   76578911.0  1.766667
# ...      ...       ...        ...          ...          ...       ...
# 45461  False         0   0.072051          NaN          0.0  1.500000
# 45462  False         0   0.178241   2011-11-17          0.0  6.000000
# 45463  False         0   0.903007   2003-08-01          0.0  1.500000
# 45464  False         0   0.003503   1917-10-21          0.0  1.450000
# 45465  False         0   0.163015   2017-06-09          0.0  1.250000
#
#                              title  vote_average
# 0                        Toy Story           7.7
# ...

# %%
meta_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   adult         45466 non-null  object
#  1   budget        45466 non-null  object
#  2   popularity    45461 non-null  object
#  3   release_date  45379 non-null  object
#  4   revenue       45460 non-null  float64
#  5   runtime       45203 non-null  float64
#  6   title         45460 non-null  object
#  7   vote_average  45460 non-null  float64
# dtypes: float64(3), object(5)
# memory usage: 2.8+ MB

# %%
meta_data.describe()
# Out:
#             revenue       runtime  vote_average
# count  4.546000e+04  45203.000000  45460.000000
# mean   1.120935e+07      1.568803      5.618207
# std    6.433225e+07      0.640130      1.924216
# min    0.000000e+00      0.000000      0.000000
# 25%    0.000000e+00      1.416667      5.000000
# 50%    0.000000e+00      1.583333      6.000000
# 75%    0.000000e+00      1.783333      6.800000
# max    2.787965e+09     20.933333     10.000000
